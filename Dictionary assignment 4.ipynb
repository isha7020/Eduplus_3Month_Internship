# %%
#1
students={
    "isha":85,"bhakti":90,"rutuja":80,"saniya":80,"shravani":70}
print(students)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 80, 'shravani': 70}

# %%
#2
print(students['isha'])
# Out:
# 85

# %%
#3
students["aditi"]=95
print(students)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 80, 'shravani': 70, 'aditi': 95}

# %%
#4
students["saniya"]=70
print(students)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 70, 'shravani': 70, 'aditi': 95}

# %%
#5
del students["shravani"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 #5
# ----> 2 del students["shravani"]
#
# KeyError: 'shravani'

# %%
print(students)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 70, 'aditi': 95}

# %%
#6
print("all students names:",students.keys())
# Out:
# all students names: dict_keys(['isha', 'bhakti', 'rutuja', 'saniya', 'aditi'])

# %%
#7
print("all students marks:",students.values())
# Out:
# all students marks: dict_values([85, 90, 80, 70, 95])

# %%
#8
print("all students with marks:",students.items())
# Out:
# all students with marks: dict_items([('isha', 85), ('bhakti', 90), ('rutuja', 80), ('saniya', 70), ('aditi', 95)])

# %%
#9
print("is rutuja in student dictionary:","rutuja" in students.keys())
# Out:
# is rutuja in student dictionary: True

# %%
#10
print("is 85 in student dictionary:",85 in students.values())
# Out:
# is 85 in student dictionary: True

# %%
#11
print("print rutuja marks:",students.get("rutuja"))
# Out:
# print rutuja marks: 80

# %%
print(students.get("Rohan", "Student not found"))
# Out:
# Student not found

# %%
#12
employees = {
    "Ravi": "HR",
    "Anita": "IT",
    "Suresh": "Finance",
    "Pooja": "Marketing"
}
print(employees)
# Out:
# {'Ravi': 'HR', 'Anita': 'IT', 'Suresh': 'Finance', 'Pooja': 'Marketing'}

# %%
#13
employees["Ravi"]
# Out:
# 'HR'

# %%
#14
employees[" Kalyani"]="Designing"
print(employees)
# Out:
# {'Ravi': 'HR', 'Anita': 'IT', 'Suresh': 'Finance', 'Pooja': 'Marketing', ' Kalyani': 'Designing'}

# %%
#15
employees['Suresh']='Operations'
print(employees)
# Out:
# {'Ravi': 'HR', 'Anita': 'IT', 'Suresh': 'Operations', 'Pooja': 'Marketing', ' Kalyani': 'Designing'}

# %%
#16
del employees['Suresh']
print(employees)
# Out:
# {'Ravi': 'HR', 'Anita': 'IT', 'Pooja': 'Marketing', ' Kalyani': 'Designing'}

# %%
#17 sort by keys
sort_ascending=dict(sorted(employees.items()))
print(sort_ascending)
# Out:
# {' Kalyani': 'Designing', 'Anita': 'IT', 'Pooja': 'Marketing', 'Ravi': 'HR'}

# %%
#18 by values
sorted_dept = dict(sorted(employees.items(), key=lambda x: x[1]))
print(sorted_dept)
# Out:
# {' Kalyani': 'Designing', 'Ravi': 'HR', 'Anita': 'IT', 'Pooja': 'Marketing'}

# %%
#19
sorted_names_desc = dict(sorted(employees.items(), reverse=True))
print(sorted_names_desc)
# Out:
# {'Ravi': 'HR', 'Pooja': 'Marketing', 'Anita': 'IT', ' Kalyani': 'Designing'}

# %%
#20
sorted_dept_desc = dict(sorted(employees.items(), key=lambda x: x[1], reverse=True))
print(sorted_dept_desc)
# Out:
# {'Pooja': 'Marketing', 'Anita': 'IT', 'Ravi': 'HR', ' Kalyani': 'Designing'}

# %%
#21
dept = "IT"
result = [k for k, v in employees.items() if v == dept]
print(result)
# Out:
# ['Anita']

# %%
result = [k for k, v in employees.items() if v == "IT"]
print(result)
# Out:
# ['Anita']

# %%
#22

count=sum(1 for m in students.values() if m>80)
print(count)
# Out:
# 3

# %%
#23
student_info = {
    "Amit": {"age": 20, "grade": "A", "department": "CS"},
    "Neha": {"age": 21, "grade": "B", "department": "IT"},
    "Rahul": {"age": 22, "grade": "A+", "department": "ECE"}
}
print(student_info)
# Out:
# {'Amit': {'age': 20, 'grade': 'A', 'department': 'CS'}, 'Neha': {'age': 21, 'grade': 'B', 'department': 'IT'}, 'Rahul': {'age': 22, 'grade': 'A+', 'department': 'ECE'}}

# %%
#24
print(student_info["Rahul"]["grade"])
# Out:
# A+

# %%
#25
student_info["Neha"]["department"] = "AI"
print(student_info)
# Out:
# {'Amit': {'age': 20, 'grade': 'A', 'department': 'CS'}, 'Neha': {'age': 21, 'grade': 'B', 'department': 'AI'}, 'Rahul': {'age': 22, 'grade': 'A+', 'department': 'ECE'}}

# %%
#26
for name, details in student_info.items():
    print(name, ":", details["grade"])
# Out:
# Amit : A
# Neha : B
# Rahul : A+

# %%
#27
students2 = {"Rohan": 79, "Meena": 91}
merged = students | students2
print(merged)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 70, 'aditi': 95, 'Rohan': 79, 'Meena': 91}

# %%
#28
students.clear()

# %%
#29
new_students = merged.copy()
new_students["Amit"] = 95
print(new_students)
# Out:
# {'isha': 85, 'bhakti': 90, 'rutuja': 80, 'saniya': 70, 'aditi': 95, 'Rohan': 79, 'Meena': 91, 'Amit': 95}

# %%
#30
squares = {i: i*i for i in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
